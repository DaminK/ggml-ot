# %% [markdown]
# # Hyperparameter Tuning

# %%
import ggml_ot
import scanpy as sc
import numpy as np

# %% [markdown]
# In this tutorial, we explore how to automatically tune important hyperparameters of ggml-ot:
#  * `alpha`: Target margin in the OT distance between distributions from the same and different classes
#  * `reg`: regularization strength on $\mathbf{A}$
#  * `reg_type`: norm used for the regularization, L1 `1`, L2 `2`, or nuclear norm `nuc`.
#  * `n_comps`: rank of the latent subspace $\mathbf{A}$

# %% [markdown]
# First, we setup the Dataset from AnnData as before. To speedup the tutorial, we subsample each patient to `n_cells=100` which can be increased (or omitted) on your own data.

# %%
id = "c1f6034b-7973-45e1-85e7-16933d0550bc.h5ad"
adata = ggml_ot.data.load_cellxgene(id)
sc.pp.highly_variable_genes(adata, n_top_genes=1000, subset=True)

# Replace patient_col and label_col names to match the .obs in your AnnData
dataset = ggml_ot.from_anndata(adata, patient_col="sample", label_col="patient_group", n_cells=100)
dataset.normalize()
# Out:
# /home/kuehn/ot_metric_learning/gaussian-ground-metric-learning/code/ggml-ot_privat/.venv/lib/python3.12/site-packages/numba/np/ufunc/parallel.py:373: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %% [markdown]
# ## Grid Search over `alpha`, `reg`, `reg_type` and `n_comps`
#
# Here, we run the hyperparameter tuning to find the best hyperparameter combination for `alpha` and `reg`. This will lead to `n_splits` train-validation splits being trained and tested for hyperparameter combination.
#
# You can also tune `reg_type` and `n_comps` with this function. In general, `n_comps=2` is sufficient and preferable for visualization purposes and fast computation, but complex datasets may require more components. The choice of regularization type mostly depends on the downstream task. For example, to identify distinct marker genes L1 is useful, whereas gene enrichment analysis should be trained with L2 to include correlated genes.
#
# *Depending on the size of your dataset, the number of splits and hyperparameter combinations, the grid search may take a while!*

# %%
# Grids for alpha (triplet margin) and reg (regularization strength)
alpha_grid = np.logspace(-1, 2, 4)  # [10^-1, 10^0, 10^1]
reg_grid = np.logspace(-4, -1, 4)  # [10^-4, 10^-3, 10^-2]

As, scores = dataset.tune(
    alpha=alpha_grid,
    reg=reg_grid,
    reg_type="fro",
    n_comps=[2, 5, 10],
    train_size=0.7,
)
# Out:
# Hyperparameter grid search:   0%|          | 0/48 [00:00<?, ?it/s]
# <style type="text/css">
# #T_42540_row0_col0 {
#   background-color: #cee5ce;
#   color: #000000;
# }
# #T_42540_row0_col8, #T_42540_row24_col8 {
#   background-color: #f9aa9c;
#   color: #000000;
# }
# #T_42540_row1_col0, #T_42540_row11_col0, #T_42540_row27_col0, #T_42540_row39_col0, #T_42540_row40_col0, #T_42540_row41_col0 {
#   background-color: #1d8e1d;
#   color: #f1f1f1;
# }
# #T_42540_row1_col8, #T_42540_row11_col8 {
#   background-color: #f7c4bb;
#   color: #000000;
# }
# #T_42540_row2_col0, #T_42540_row8_col0, #T_42540_row24_col0, #T_42540_row26_col0, #T_42540_row32_col0, #T_42540_row37_col0, #T_42540_row42_col0, #T_42540_row44_col0, #T_42540_row47_col0 {
#   background-color: #58ab58;
#   color: #f1f1f1;
# }
# #T_42540_row2_col8 {
#   background-color: #f8b6ab;
#   color: #000000;
# }
# #T_42540_row3_col0, #T_42540_row12_col0, #T_42540_row14_col0, #T_42540_row17_col0, #T_42540_row23_col0, #T_42540_row29_col0, #T_42540_row34_col0 {
#   background-color: #93c893;
#   color: #000000;
# }
# #T_42540_row3_col8 {
#   background-color: #f7c2b9;
#   color: #000000;
# }
# #T_42540_row4_col0, #T_42540_row13_col0, #T_42540_row15_col0, #T_42540_row16_col0 {
#   background-color: #b0d6b0;
#   color: #000000;
# }
# #T_42540_row4_col8 {
#   background-color: #f8b3a7;
#   color: #000000;
# }
# #T_42540_row5_col0, #T_42540_row7_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_42540_row5_col8, #T_42540_row12_col8 {
#   background-color: #f9aea1;
#   color: #000000;
# }
# #T_42540_row6_col0, #T_42540_row9_col0, #T_42540_row10_col0, #T_42540_row20_col0, #T_42540_row28_col0, #T_42540_row30_col0, #T_42540_row31_col0, #T_42540_row45_col0 {
#   background-color: #75b975;
#   color: #f1f1f1;
# }
# #T_42540_row6_col8 {
#   background-color: #f6d0c9;
#   color: #000000;
# }
# #T_42540_row7_col8 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_42540_row8_col8 {
#   background-color: #f6c9c1;
#   color: #000000;
# }
# #T_42540_row9_col8 {
#   background-color: #f7bdb2;
#   color: #000000;
# }
# #T_42540_row10_col8 {
#   background-color: #f6c8bf;
#   color: #000000;
# }
# #T_42540_row13_col8 {
#   background-color: #f8b5a9;
#   color: #000000;
# }
# #T_42540_row14_col8 {
#   background-color: #f7c3b9;
#   color: #000000;
# }
# #T_42540_row15_col8 {
#   background-color: #f8baaf;
#   color: #000000;
# }
# #T_42540_row16_col8 {
#   background-color: #fa9b8a;
#   color: #000000;
# }
# #T_42540_row17_col8, #T_42540_row39_col8 {
#   background-color: #fa9d8c;
#   color: #000000;
# }
# #T_42540_row18_col0 {
#   background-color: #57ab57;
#   color: #f1f1f1;
# }
# #T_42540_row18_col8, #T_42540_row44_col8 {
#   background-color: #faa292;
#   color: #000000;
# }
# #T_42540_row19_col0, #T_42540_row33_col0, #T_42540_row35_col0, #T_42540_row38_col0 {
#   background-color: #76ba76;
#   color: #f1f1f1;
# }
# #T_42540_row19_col8, #T_42540_row30_col8 {
#   background-color: #f9ad9f;
#   color: #000000;
# }
# #T_42540_row20_col8 {
#   background-color: #f9a99a;
#   color: #000000;
# }
# #T_42540_row21_col0, #T_42540_row36_col0 {
#   background-color: #b1d7b1;
#   color: #000000;
# }
# #T_42540_row21_col8, #T_42540_row28_col8 {
#   background-color: #faa090;
#   color: #000000;
# }
# #T_42540_row22_col0 {
#   background-color: #92c892;
#   color: #000000;
# }
# #T_42540_row22_col8 {
#   background-color: #f9a494;
#   color: #000000;
# }
# #T_42540_row23_col8 {
#   background-color: #f9a394;
#   color: #000000;
# }
# #T_42540_row25_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_42540_row25_col1, #T_42540_row25_col2, #T_42540_row25_col3, #T_42540_row25_col4, #T_42540_row25_col5, #T_42540_row25_col6, #T_42540_row25_col7, #T_42540_row25_col9 {
#   font-weight: bold;
# }
# #T_42540_row25_col8 {
#   background-color: #fa9d8c;
#   color: #000000;
#   font-weight: bold;
# }
# #T_42540_row26_col8 {
#   background-color: #f7bfb5;
#   color: #000000;
# }
# #T_42540_row27_col8 {
#   background-color: #ff6347;
#   color: #f1f1f1;
# }
# #T_42540_row29_col8 {
#   background-color: #fb917e;
#   color: #000000;
# }
# #T_42540_row31_col8 {
#   background-color: #fb9481;
#   color: #000000;
# }
# #T_42540_row32_col8 {
#   background-color: #fb907d;
#   color: #000000;
# }
# #T_42540_row33_col8 {
#   background-color: #fa9987;
#   color: #000000;
# }
# #T_42540_row34_col8, #T_42540_row38_col8 {
#   background-color: #fa9f8f;
#   color: #000000;
# }
# #T_42540_row35_col8 {
#   background-color: #fb8f7c;
#   color: #000000;
# }
# #T_42540_row36_col8 {
#   background-color: #fc836d;
#   color: #f1f1f1;
# }
# #T_42540_row37_col8 {
#   background-color: #fb9583;
#   color: #000000;
# }
# #T_42540_row40_col8 {
#   background-color: #fb917f;
#   color: #000000;
# }
# #T_42540_row41_col8 {
#   background-color: #fd7c65;
#   color: #f1f1f1;
# }
# #T_42540_row42_col8 {
#   background-color: #fa9886;
#   color: #000000;
# }
# #T_42540_row43_col0, #T_42540_row46_col0 {
#   background-color: #3b9d3b;
#   color: #f1f1f1;
# }
# #T_42540_row43_col8 {
#   background-color: #fc8a75;
#   color: #f1f1f1;
# }
# #T_42540_row45_col8 {
#   background-color: #faa191;
#   color: #000000;
# }
# #T_42540_row46_col8 {
#   background-color: #f9a899;
#   color: #000000;
# }
# #T_42540_row47_col8 {
#   background-color: #fa9887;
#   color: #000000;
# }
# </style>
# <table id="T_42540">
#   <caption>Hyperparameter tuning</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_42540_level0_col0" class="col_heading level0 col0" colspan="2">knn_acc</th>
#       <th id="T_42540_level0_col2" class="col_heading level0 col2" colspan="2">mi</th>
#       <th id="T_42540_level0_col4" class="col_heading level0 col4" colspan="2">ari</th>
#       <th id="T_42540_level0_col6" class="col_heading level0 col6" colspan="2">vi</th>
#       <th id="T_42540_level0_col8" class="col_heading level0 col8" colspan="2">epoch_time(s)</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Mean±SD</th>
#       <th id="T_42540_level1_col0" class="col_heading level1 col0" >Mean</th>
#       <th id="T_42540_level1_col1" class="col_heading level1 col1" >SD</th>
#       <th id="T_42540_level1_col2" class="col_heading level1 col2" >Mean</th>
#       <th id="T_42540_level1_col3" class="col_heading level1 col3" >SD</th>
#       <th id="T_42540_level1_col4" class="col_heading level1 col4" >Mean</th>
#       <th id="T_42540_level1_col5" class="col_heading level1 col5" >SD</th>
#       <th id="T_42540_level1_col6" class="col_heading level1 col6" >Mean</th>
#       <th id="T_42540_level1_col7" class="col_heading level1 col7" >SD</th>
#       <th id="T_42540_level1_col8" class="col_heading level1 col8" >Mean</th>
#       <th id="T_42540_level1_col9" class="col_heading level1 col9" >SD</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >n_comps</th>
#       <th class="index_name level1" >reg_type</th>
#       <th class="index_name level2" >alpha</th>
#       <th class="index_name level3" >reg</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42540_level0_row0" class="row_heading level0 row0" rowspan="16">2</th>
#       <th id="T_42540_level1_row0" class="row_heading level1 row0" rowspan="16">fro</th>
#       <th id="T_42540_level2_row0" class="row_heading level2 row0" rowspan="4">0.10</th>
#       <th id="T_42540_level3_row0" class="row_heading level3 row0" >0.00</th>
#       <td id="T_42540_row0_col0" class="data row0 col0" >0.73</td>
#       <td id="T_42540_row0_col1" class="data row0 col1" >0.11</td>
#       <td id="T_42540_row0_col2" class="data row0 col2" >0.72</td>
#       <td id="T_42540_row0_col3" class="data row0 col3" >0.09</td>
#       <td id="T_42540_row0_col4" class="data row0 col4" >0.68</td>
#       <td id="T_42540_row0_col5" class="data row0 col5" >0.12</td>
#       <td id="T_42540_r

# %% [markdown]
# Once tuning is complete, the function displays the performance of each hyperparameter combination on the validation set and returns:
# - `As`: a dict containing the learned transformations for each parameter combination (with the best performance across splits)
# - `scores`: a dataframe of the performance of the considered hyperparameter combination, as shown above.
#
# Using the `scores` dataframe and contour_hyperparams plotting fucntion, you can plot other parameter combinations and evaluation metrics as shown below:

# %%
# ARI over alpha and reg
ggml_ot.pl.contour_hyperparams(
    scores, x="alpha", y="reg", fixed_params={"reg_type": "fro", "n_comps": 2}, value_col=("ari", "mean"), levels=20
)

# Epoch time over n_comps and reg
ggml_ot.pl.contour_hyperparams(
    scores,
    x="n_comps",
    y="reg",
    fixed_params={"reg_type": "fro"},
    value_col=("epoch_time(s)", "mean"),
    log_axis="y",
    levels=20,
)
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: xlabel='n_comps', ylabel='reg'>)

# %% [markdown]
# ## Access best performing hyperparameters
#
# To get the best performing hyperparameters you can call `.idxmax()` on the respective column (e.g. mean classification accuracy `("knn","mean")`) of the scores dataframe that the hyperparameter tuning returned.

# %%
best_params = scores[("knn", "mean")].idxmax()
print("as tupple to access As and scores: " + str(best_params))

# Cast numpy scalars (np.int64, np.float64) to Python scalars for cleaner printing and kwargs
best_params_dict = {p: (v.item() if hasattr(v, "item") else v) for p, v in zip(scores.index.names, best_params)}
print("as dict to pass as parameters: " + str(best_params_dict))
# Out:
# as tupple to access As and scores: (np.int64(5), 'fro', np.float64(10.0), np.float64(0.001))
# as dict to pass as parameters: {'n_comps': 5, 'reg_type': 'fro', 'alpha': 10.0, 'reg': 0.001}

# %% [markdown]
# We can also rerun the training (and testing) with the learned hyperparameters to show that the identified parameters reliable learn a performant ground metric.

# %%
_ = dataset.train_test(**best_params_dict, plot_split=False)
# Out:
# <style type="text/css">
# #T_ac56e_row0_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
#   font-weight: bold;
# }
# #T_ac56e_row0_col1, #T_ac56e_row0_col2, #T_ac56e_row0_col3, #T_ac56e_row0_col4, #T_ac56e_row0_col5, #T_ac56e_row0_col6, #T_ac56e_row0_col7, #T_ac56e_row0_col9 {
#   font-weight: bold;
# }
# #T_ac56e_row0_col8 {
#   background-color: #f3f0f0;
#   color: #000000;
#   font-weight: bold;
# }
# #T_ac56e_level0_row0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_ac56e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th id="T_ac56e_level0_col0" class="col_heading level0 col0" colspan="2">knn_acc</th>
#       <th id="T_ac56e_level0_col2" class="col_heading level0 col2" colspan="2">mi</th>
#       <th id="T_ac56e_level0_col4" class="col_heading level0 col4" colspan="2">ari</th>
#       <th id="T_ac56e_level0_col6" class="col_heading level0 col6" colspan="2">vi</th>
#       <th id="T_ac56e_level0_col8" class="col_heading level0 col8" colspan="2">epoch_time(s)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Mean±SD</th>
#       <th id="T_ac56e_level1_col0" class="col_heading level1 col0" >Mean</th>
#       <th id="T_ac56e_level1_col1" class="col_heading level1 col1" >SD</th>
#       <th id="T_ac56e_level1_col2" class="col_heading level1 col2" >Mean</th>
#       <th id="T_ac56e_level1_col3" class="col_heading level1 col3" >SD</th>
#       <th id="T_ac56e_level1_col4" class="col_heading level1 col4" >Mean</th>
#       <th id="T_ac56e_level1_col5" class="col_heading level1 col5" >SD</th>
#       <th id="T_ac56e_level1_col6" class="col_heading level1 col6" >Mean</th>
#       <th id="T_ac56e_level1_col7" class="col_heading level1 col7" >SD</th>
#       <th id="T_ac56e_level1_col8" class="col_heading level1 col8" >Mean</th>
#       <th id="T_ac56e_level1_col9" class="col_heading level1 col9" >SD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac56e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac56e_row0_col0" class="data row0 col0" >0.85</td>
#       <td id="T_ac56e_row0_col1" class="data row0 col1" >0.06</td>
#       <td id="T_ac56e_row0_col2" class="data row0 col2" >0.80</td>
#       <td id="T_ac56e_row0_col3" class="data row0 col3" >0.08</td>
#       <td id="T_ac56e_row0_col4" class="data row0 col4" >0.79</td>
#       <td id="T_ac56e_row0_col5" class="data row0 col5" >0.11</td>
#       <td id="T_ac56e_row0_col6" class="data row0 col6" >0.38</td>
#       <td id="T_ac56e_row0_col7" class="data row0 col7" >0.15</td>
#       <td id="T_ac56e_row0_col8" class="data row0 col8" >1.34</td>
#       <td id="T_ac56e_row0_col9" class="data row0 col9" >0.11</td>
#     </tr>
#   </tbody>
# </table>
